# %%
import pandas as pd

# Read the parquet file

df = pd.read_parquet(r'Data\0__signals.parquet')

# Remove rows with any NaN values
df = df.dropna()

print(df.shape)
print(df.head())
##save the cleaned dataframe to the same parquet file
df.to_parquet(r'Data\0__signals.parquet', index=False)
# Out:
# (0, 26)
# Empty DataFrame
# Columns: [Symbol, Status, TargetDate, CurrentPrice, SignalPrice, EntryPrice, StopPrice, TargetPrice, UpProbability, ATR, SignalStrength, SignalDate, CreatedDate, LastUpdated, LastUpdate, PositionSize, PnL, PnLPct, ExitPrice, EntryDate, ExitDate, ExitReason, ConsecutiveLosses, CapBucket, CapMillions, Sentiment]
# Index: []
#
# [0 rows x 26 columns]
